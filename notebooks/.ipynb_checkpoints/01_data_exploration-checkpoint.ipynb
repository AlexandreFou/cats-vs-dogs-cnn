# %%
import os
from pathlib import Path
import matplotlib.pyplot as plt
from PIL import Image

# Chemins
train_dir = Path("data/train")
classes = ["cats_set", "dogs_set"]

# Afficher quelques images
fig, axes = plt.subplots(2, 5, figsize=(12,5))
for i, cls in enumerate(classes):
    cls_path = train_dir/cls
    imgs = list(cls_path.iterdir())[:5]  # prendre 5 images
    for j, img_path in enumerate(imgs):
        img = Image.open(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis("off")
        axes[i, j].set_title(cls)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 14
#      12 for i, cls in enumerate(classes):
#      13     cls_path = train_dir/cls
# ---> 14     imgs = list(cls_path.iterdir())[:5]  # prendre 5 images
#      15     for j, img_path in enumerate(imgs):
#      16         img = Image.open(img_path)
#
# File c:\Users\Alexandre\AppData\Local\Programs\Python\Python310\lib\pathlib.py:1017, in Path.iterdir(self)
#    1013 def iterdir(self):
#    1014     """Iterate over the files in this directory.  Does not yield any
#    1015     result for the special paths '.' and '..'.
#    1016     """
# -> 1017     for name in self._accessor.listdir(self):
#    1018         if name in {'.', '..'}:
#    1019             # Yielding a path object for these makes little sense
#    1020             continue
#
# FileNotFoundError: [WinError 3] Le chemin d’accès spécifié est introuvable: 'data\\train\\cats'
