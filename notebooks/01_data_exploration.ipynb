# %%
from pathlib import Path
print("Notebook cwd:", Path.cwd())
print("Existe ../data ? ", (Path("../data")).exists())
print("Existe ../../data ? ", (Path("../../data")).exists())
# Out:
# Notebook cwd: C:\Users\Alexandre\OneDrive\Bureau\dev ai\BigProjects\Dogs-vs-cats-classifier\notebooks
# Existe ../data ?  True
# Existe ../../data ?  False

# %%
import os
from pathlib import Path
import matplotlib.pyplot as plt
from PIL import Image

# Chemins
train_dir = Path("../data")
classes = ["cats_set", "dogs_set"]


# Afficher quelques images
fig, axes = plt.subplots(2, 5, figsize=(12,5))
for i, cls in enumerate(classes):
    cls_path = train_dir/cls
    imgs = list(cls_path.iterdir())[:5]  # prendre 5 images
    for j, img_path in enumerate(imgs):
        img = Image.open(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis("off")
        axes[i, j].set_title(cls)
plt.show()
